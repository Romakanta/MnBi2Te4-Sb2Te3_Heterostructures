# %% [markdown]
# ## Random forest regression on magnetic moment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#!pip install scikeras
from sklearn import metrics,linear_model
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import Ridge, BayesianRidge, Lasso, RidgeCV, LassoCV, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, RepeatedKFold
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor,RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix, mean_squared_error, r2_score
# Out:
# C:\Users\Romakanta\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df= pd.read_excel("withDescriptors_DFT_D3_ACS_AMI_348_hetero_Ef_Eg.xlsx")

# %%
df.head()
# Out:
#               material spin_state  formation_energy  Ef_per_cell  bandgap  \
# 0  Mn1Sc1Bi4Se8_Sn4Te6         FM        -15.411348    -7.705674      0.0
# 1   Mn1Y1Sb4Se8_Sn4Te6         FM        -14.759108    -7.379554      0.0
# 2  Mn1Ag1Sb4Te8_Sn4Te6         FM         -9.713931    -4.856966      0.0
# 3   Mn1Rh1Sb4S8_Sn4Se6        AFM        -13.765300    -6.882650      0.0
# 4  Mn1Zr1Pb4Te8_Sb4Te6         FM        -12.878048    -6.439024      0.0
#
#                                        mag_mom_table  \
# 0  [('x', ['s', 'p', 'd', 'tot'], [[-0.001, -0.00...
# 1  [('x', ['s', 'p', 'd', 'f', 'tot'], [[-0.0, -0...
# 2  [('x', ['s', 'p', 'd', 'tot'], [[-0.0, -0.0, -...
# 3  [('x', ['s', 'p', 'd', 'tot'], [[-0.0, -0.0, -...
# 4  [('x', ['s', 'p', 'd', 'tot'], [[0.001, 0.0, 0...
#
#                             sitewise_axiswise_tot_mu  \
# 0  [[-0.102, -0.051, 4.577], [-0.001, -0.0, 0.015...
# 1  [[-0.01, -0.004, 4.57], [-0.0, -0.0, 0.009], [...
# ...

# %%
# df.describe()

# %%
# df.columns

# %%
X_mu = df[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
           'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
           'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
           'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
           'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
           'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
           'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
           'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
           'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
           'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
           'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
           'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

y_mu = df[['Mu_per_cell']]

feature_list = list(X_mu.columns)

X_mu = np.array(X_mu)
y_mu = np.array(y_mu)

# %%
X_mu.shape
# Out:
# (348, 55)

# %%
r2_scores_train = []
r2_scores_val = []
r2_scores_test = []
random_states = []
for i in range(100):
    
    X_train_mu,X_test_mu,y_train_mu,y_test_mu = train_test_split(X_mu, y_mu, test_size=0.2, random_state=i)#, stratify = y)
    X_train_mu,X_val_mu,y_train_mu,y_val_mu = train_test_split(X_train_mu, y_train_mu,test_size=0.25,random_state=i)#, stratify = y)

    rf_mu = RandomForestRegressor(n_estimators = 30, random_state=i)
    rf_mu.fit(X_train_mu, y_train_mu)

    prediction_mu_train = rf_mu.predict(X_train_mu)
    prediction_mu_val = rf_mu.predict(X_val_mu)
    prediction_mu_test = rf_mu.predict(X_test_mu)

    r2_scores_train.append(metrics.r2_score(y_train_mu,prediction_mu_train))
    r2_scores_val.append(metrics.r2_score(y_val_mu,prediction_mu_val))
    r2_scores_test.append(metrics.r2_score(y_test_mu,prediction_mu_test))
    random_states.append(i)
# Out:
# C:\Users\ROMAKA~1\AppData\Local\Temp/ipykernel_16764/1788494440.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_mu.fit(X_train_mu, y_train_mu)
# C:\Users\ROMAKA~1\AppData\Local\Temp/ipykernel_16764/1788494440.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_mu.fit(X_train_mu, y_train_mu)
# C:\Users\ROMAKA~1\AppData\Local\Temp/ipykernel_16764/1788494440.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_mu.fit(X_train_mu, y_train_mu)
# ...

# %%
plt.figure(figsize=(20,10))
plt.scatter(random_states,r2_scores_train)
plt.scatter(random_states,r2_scores_val)
plt.scatter(random_states,r2_scores_test)

# %%
for i in range(100):
    print(random_states[i], r2_scores_train[i], r2_scores_val[i], r2_scores_test[i])
# Out:
# 0 0.9263342450633061 0.19317129057006477 0.5363302510263085
# 1 0.9293968791705612 0.46379878952284537 0.5996952266764165
# 2 0.9352971213096262 0.5217136426621267 0.5358129484085982
# 3 0.9088313060094875 0.5367716523734019 0.46208791289033846
# 4 0.9212756535349138 0.4643819899051257 0.48586540936147604
# 5 0.9114349163603235 0.44553960466992604 0.5163029621971782
# 6 0.9107255623674337 0.43059476611471537 0.41079880725726714
# 7 0.8975242167595467 0.4774478589986434 0.5569459241030712
# 8 0.9114896456382353 0.4535976992315771 0.6690270240068816
# 9 0.9057400553609765 0.4152230308131091 0.2981789619651266
# 10 0.9047706955643626 0.29911886541470367 0.6866364640372384
# 11 0.9195401622889312 0.3199762753949288 0.3895268425100482
# 12 0.9164533698648981 0.5074251513300734 0.5389341078552563
# 13 0.9199504775247687 0.6071801659442116 0.45156688514602494
# 14 0.930346377613172 0.46076569396966904 0.21490761025285032
# 15 0.9100656920671824 0.45752206898856274 0.5287705009413373
# ...

# %% [markdown]
# ## BELOW IS NOT MU, IT IS FORMATION ENERGY FROM PREVIOUS EF MODEL

# %%
X_train_ef,X_test_ef,y_train_ef,y_test_ef = train_test_split(X_ef, y_ef, test_size=0.2, random_state=16)#, stratify = y)
X_train_ef,X_val_ef,y_train_ef,y_val_ef = train_test_split(X_train_ef, y_train_ef,test_size=0.25,random_state=16)#, stratify = y)

rf_ef = RandomForestRegressor(n_estimators = 30, random_state=16)
rf_ef.fit(X_train_ef, y_train_ef)

prediction_ef_train = rf_ef.predict(X_train_ef)
prediction_ef_val = rf_ef.predict(X_val_ef)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_val)))
print('\n')
print('Root mean squared error of training set: {:0.3f}'.format(sqrt(metrics.mean_squared_error(y_train_ef,prediction_ef_train))))
print('Root mean squared error of validation set: {:0.3f}'.format(sqrt(metrics.mean_squared_error(y_val_ef,prediction_ef_val))))
print('\n')
r_sq_ef_train = metrics.r2_score(y_train_ef,prediction_ef_train)
r_sq_ef_val = metrics.r2_score(y_val_ef,prediction_ef_val)

print('R^2 score on training data: {:0.3f}'.format(r_sq_ef_train))
print('R^2 score on validation data: {:0.3f}'.format(r_sq_ef_val))
# Out:
# Mean absolute error of training set: 0.109
# Mean absolute error of validation set: 0.212
#
#
# Root mean squared error of training set: 0.155
# Root mean squared error of validation set: 0.310
#
#
# R^2 score on training data: 0.975
# R^2 score on validation data: 0.902
# C:\Users\ROMAKA~1\AppData\Local\Temp/ipykernel_7140/3816205447.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_ef.fit(X_train_ef, y_train_ef)

# %%
prediction_ef_test = rf_ef.predict(X_test_ef)
r_sq_ef_test = metrics.r2_score(y_test_ef,prediction_ef_test)

print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_test)))
print('Root mean squared error of test set: {:0.3f}'.format(sqrt(metrics.mean_squared_error(y_test_ef,prediction_ef_test))))
print('R^2 score on test data: {:0.3f}'.format(r_sq_ef_test))

plt.figure(figsize = (15,10))
plt.scatter(y_train_ef,prediction_ef_train ,color = 'g', s=100, marker='o', label='Training set')
plt.scatter(y_test_ef,prediction_ef_test, color = 'r', s=100, marker='s', label='Test set')
plt.plot([-9,-4],[-9,-4])
plt.xlabel('Calculated Energy'),plt.ylabel('Predicted Energy')
plt.xlabel('Calculated Energy'),plt.ylabel('Predicted Energy')
plt.legend()
plt.show()
# Out:
# Mean absolute error of test set: 0.218
# Root mean squared error of test set: 0.287
# R^2 score on test data: 0.927

# %%
plt.figure(figsize = (7,7))
plt.scatter(y_train_ef,prediction_ef_train ,color = 'g', s=100, marker='o', label='Training set')
plt.scatter(y_test_ef,prediction_ef_test, color = 'r', s=100, marker='s', label='Test set')
plt.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
plt.xlabel('Calculated Energy'),plt.ylabel('Predicted Energy')
plt.legend()
plt.show()

# %%
X_train_ef_pd = pd.DataFrame(X_train_ef)
X_val_ef_pd = pd.DataFrame(X_val_ef)
X_test_ef_pd = pd.DataFrame(X_test_ef)

y_train_ef_pd = pd.DataFrame(y_train_ef)
y_val_ef_pd = pd.DataFrame(y_val_ef)
y_test_ef_pd = pd.DataFrame(y_test_ef)

X_train_ef_pd.to_csv('X_train_ef_RF.csv',index=False)
X_val_ef_pd.to_csv('X_val_ef_RF.csv',index=False)
X_test_ef_pd.to_csv('X_test_ef_RF.csv',index=False)

y_train_ef_pd.to_csv('y_train_ef_RF.csv',index=False)
y_val_ef_pd.to_csv('y_val_ef_RF.csv',index=False)
y_test_ef_pd.to_csv('y_test_ef_RF.csv',index=False)

# %%
## Data from FFNN model

# %%
X_train = pd.read_csv('Results_Ef/X_train_FFNN.csv')
X_val = pd.read_csv('Results_Ef/X_val_FFNN.csv')
X_test = pd.read_csv('Results_Ef/X_test_FFNN.csv')

y_train = pd.read_csv('Results_Ef/y_train_FFNN.csv')
y_val = pd.read_csv('Results_Ef/y_val_FFNN.csv')
y_test = pd.read_csv('Results_Ef/y_test_FFNN.csv')

# %%
y_train_ef = y_train['55']
y_val_ef = y_val['55']
y_test_ef = y_test['55']

# %%
rf_ef = RandomForestRegressor(n_estimators = 30, random_state=16)
rf_ef.fit(X_train, y_train_ef)

prediction_ef_train = rf_ef.predict(X_train)
prediction_ef_val = rf_ef.predict(X_val)
prediction_ef_test = rf_ef.predict(X_test)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_val)))
print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_test)))
print('\n')
r_sq_ef_train = metrics.r2_score(y_train_ef,prediction_ef_train)
r_sq_ef_val = metrics.r2_score(y_val_ef,prediction_ef_val)
r_sq_ef_test = metrics.r2_score(y_test_ef,prediction_ef_test)

print('R^2 score on training data: {:0.3f}'.format(r_sq_ef_train))
print('R^2 score on validation data: {:0.3f}'.format(r_sq_ef_val))
print('R^2 score on test data: {:0.3f}'.format(r_sq_ef_test))
print('\n')

plt.figure(figsize = (15,10))
plt.scatter(y_train_ef,prediction_ef_train ,color = 'g', s=100, marker='o', label='Training set')
plt.scatter(y_test_ef,prediction_ef_test, color = 'r', s=100, marker='s', label='Test set')
plt.plot([-9,-4],[-9,-4])
plt.xlabel('Calculated Energy'),plt.ylabel('Predicted Energy')
plt.xlabel('Calculated Energy'),plt.ylabel('Predicted Energy')
plt.legend()
plt.show()
# Out:
# Mean absolute error of training set: 0.091
# Mean absolute error of validation set: 0.280
# Mean absolute error of test set: 0.269
#
#
# R^2 score on training data: 0.983
# R^2 score on validation data: 0.816
# R^2 score on test data: 0.897

# %%
plt.figure(figsize = (7,7))
plt.scatter(y_train_ef,prediction_ef_train ,color = 'g', s=100, marker='o', label='Training set')
plt.scatter(y_test_ef,prediction_ef_test, color = 'r', s=100, marker='s', label='Test set')
plt.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
plt.xlabel('Calculated Energy'),plt.ylabel('Predicted Energy')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (7,7))
plt.scatter(y_train_ef,prediction_ef_train ,color = 'g', s=100, marker='o', label='Training set')
plt.scatter(y_val_ef,prediction_ef_val, color = 'b', s=100, marker='^', label='Val set')
plt.scatter(y_test_ef,prediction_ef_test, color = 'r', s=100, marker='s', label='Test set')
plt.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
plt.xlabel('Calculated Energy'),plt.ylabel('Predicted Energy')
plt.legend()
plt.show()

# %%
print('max_depth: ', rf_ef.max_depth)
print('max_features: ', rf_ef.max_features)
print('min_samples_leaf: ', rf_ef.min_samples_leaf)
print('min_samples_split: ', rf_ef.min_samples_split)
print('n_estimators: ', rf_ef.n_estimators)

# max_depth:  None
# max_features:  1.0
# min_samples_leaf:  1
# min_samples_split:  2
# n_estimators:  30
# Out:
# max_depth:  None
# max_features:  1.0
# min_samples_leaf:  1
# min_samples_split:  2
# n_estimators:  30

# %%
pd.DataFrame(prediction_ef_train).to_csv('Results_Ef/y_pred_train_ef_RF.csv',index=False)
pd.DataFrame(prediction_ef_val).to_csv('Results_Ef/y_pred_val_ef_RF.csv',index=False)
pd.DataFrame(prediction_ef_test).to_csv('Results_Ef/y_pred_test_ef_RF.csv',index=False)

# %%
# ## Running 10 times

# r2_train = []
# r2_val = []
# r2_test = []

# mae_train = []
# mae_val = []
# mae_test = []

# for i in range(10):
    
#     rf_ef_10 = RandomForestRegressor(n_estimators = 30)
#     rf_ef_10.fit(X_train_ef, y_train_ef.ravel())

#     prediction_ef_train_10 = rf_ef_10.predict(X_train_ef)
#     prediction_ef_val_10 = rf_ef_10.predict(X_val_ef)
#     prediction_ef_test_10 = rf_ef_10.predict(X_test_ef)

#     mae_train.append(metrics.mean_absolute_error(y_train_ef,prediction_ef_train_10))
#     mae_val.append(metrics.mean_absolute_error(y_val_ef,prediction_ef_val_10))
#     mae_test.append(metrics.mean_absolute_error(y_test_ef,prediction_ef_test_10))
    
#     r2_train.append(metrics.r2_score(y_train_ef,prediction_ef_train_10))
#     r2_val.append(metrics.r2_score(y_val_ef,prediction_ef_val_10))
#     r2_test.append(metrics.r2_score(y_test_ef,prediction_ef_test_10))

# %%
# print('Average r2 of training set: {:0.4f}'.format(np.mean(r2_train)))
# print('Average r2 of validation set: {:0.4f}'.format(np.mean(r2_val)))
# print('Average r2 of test set: {:0.4f}'.format(np.mean(r2_test)))

# print('\n')
# print('Average MAE of training set: {:0.4f}'.format(np.mean(mae_train)))
# print('Average MAE of validation set: {:0.4f}'.format(np.mean(mae_val)))
# print('Average MAE of test set: {:0.4f}'.format(np.mean(mae_test)))

# %%
df.columns[26:]
# Out:
# Index(['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius',
#        'max_diff_vdw_radius', 'std_vdw_radius', 'avg_covalent_radius',
#        'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius',
#        'max_diff_covalent_radius', 'std_covalent_radius', 'avg_atomic_radius',
#        'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius',
#        'max_diff_atomic_radius', 'std_atomic_radius', 'avg_atomic_volume',
#        'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume',
#        'max_diff_atomic_volume', 'std_atomic_volume',
#        'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability',
#        'delta_bx_dipole_polarizability', 'max_diff_dipole_polarizability',
#        'std_dipole_polarizability', 'avg_val_electrons',
#        'delta_a1a2_val_electrons', 'delta_bx_val_electrons',
#        'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons',
#        'delta_a1a2_unp_electrons', 'delta_bx_unp_electrons',
# ...

# %%
importances_ef = rf_ef.feature_importances_
indices_ef = np.argsort(importances_ef)[::-1]  ## without [::-1] gives ascending order

plt.figure(figsize=(20,10))
plt.ylabel('Feature Importance')
plt.xlabel('Descriptors')
plt.bar(range(X_train.shape[1]), importances_ef[indices_ef], align='center')
desc_labels = df.columns[26:]
plt.xticks(range(X_train.shape[1]), desc_labels[indices_ef],  rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %%
# Extract the features importance

data_feature_imp = {'feature': desc_labels[indices_ef],
                   'importance':importances_ef[indices_ef]}
pd_feature_imp = pd.DataFrame(data_feature_imp)
pd_feature_imp.to_csv('Results_Ef/feature_importance_ef_RF.csv',index=False)

# %%
desc_labels[indices_ef][:6]
# Out:
# Index(['std_vdw_radius', 'std_electronegativity', 'max_diff_ion_energies',
#        'avg_val_electrons', 'avg_atomic_volume', 'std_dipole_polarizability'],
#       dtype='object')

# %%
plt.figure(figsize=(7,7))
plt.ylabel('Feature Importance')
plt.xlabel('Descriptors')
plt.bar(range(6), importances_ef[indices_ef][:6], align='center')
desc_labels = df.columns[26:]
plt.xticks(range(6), desc_labels[indices_ef][:6],  rotation=90)
plt.xlim([-0.5, 5.5])
plt.show()

# %%
## Scatter plots of top 15 descriptors

# %%
fig, ax = plt.subplots(nrows = 5, ncols = 3, figsize = (18, 30))

nrows = 5
ncols = 3
count = 0
for i in range(nrows):
    for j in range(ncols):
        
        ax[i,j].scatter(df[desc_labels[indices_ef][count]],df['Ef_per_cell'])
        ax[i,j].set_xlabel(''), ax[i,j].set_ylabel('Ef_per_cell'), ax[i,j].set_title(desc_labels[indices_ef][count])
        
        count = count+1

plt.show()

# %%
# fig,((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(nrows=2,ncols=3,figsize=(18,12))


# ax1.scatter(df[desc_labels[indices_ef][0]],df['Ef_per_cell'])
# ax1.set_xlabel(''),ax1.set_ylabel('Ef_per_cell'), ax1.set_title(desc_labels[indices_ef][0])

# ax2.scatter(df[desc_labels[indices_ef][1]],df['Ef_per_cell'])
# ax2.set_xlabel(''),ax2.set_ylabel(''), ax2.set_title(desc_labels[indices_ef][1])

# ax3.scatter(df[desc_labels[indices_ef][2]],df['Ef_per_cell'])
# ax3.set_xlabel('descriptors'),ax3.set_ylabel(''), ax3.set_title(desc_labels[indices_ef][2])

# ax4.scatter(df[desc_labels[indices_ef][3]],df['Ef_per_cell'])
# ax4.set_xlabel('descriptors'),ax4.set_ylabel('Ef_per_cell'), ax4.set_title(desc_labels[indices_ef][3])

# ax5.scatter(df[desc_labels[indices_ef][4]],df['Ef_per_cell'])
# ax5.set_xlabel(''),ax5.set_ylabel(''), ax5.set_title(desc_labels[indices_ef][4])

# ax6.scatter(df[desc_labels[indices_ef][5]],df['Ef_per_cell'])
# ax6.set_xlabel('descriptors'),ax6.set_ylabel(''), ax6.set_title(desc_labels[indices_ef][5])

# plt.show()

# %%
## With 6 best features

# %%
best_features_6 = desc_labels[indices_ef][:6]
best_indices_6 = [feature_list.index(i) for i in best_features_6]

X_train_best_6 = X_train[X_train.columns[best_indices_6]]
X_val_best_6 = X_val[X_val.columns[best_indices_6]]
X_test_best_6 = X_test[X_test.columns[best_indices_6]]

rf_ef_best_6 = RandomForestRegressor(n_estimators = 30, random_state=16)
rf_ef_best_6.fit(X_train_best_6, y_train_ef)

prediction_ef_best_6_train = rf_ef_best_6.predict(X_train_best_6)
prediction_ef_best_6_val = rf_ef_best_6.predict(X_val_best_6)
prediction_ef_best_6_test = rf_ef_best_6.predict(X_test_best_6)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_best_6_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_best_6_val)))
print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_best_6_test)))
print('\n')

r_sq_ef_best_6_train = metrics.r2_score(y_train_ef,prediction_ef_best_6_train)
r_sq_ef_best_6_val = metrics.r2_score(y_val_ef,prediction_ef_best_6_val)
r_sq_ef_best_6_test = metrics.r2_score(y_test_ef,prediction_ef_best_6_test)

print('R^2 score on training data: {:0.3f}'.format(r_sq_ef_best_6_train))
print('R^2 score on validation data: {:0.3f}'.format(r_sq_ef_best_6_val))
print('R^2 score on test data: {:0.3f}'.format(r_sq_ef_best_6_test))

fig,(ax1,ax2) = plt.subplots(1,2,figsize = (15,7))
ax1.scatter(y_train_ef,prediction_ef_best_6_train ,color = 'g', s=100, marker='o', label='Training set')
ax1.scatter(y_val_ef,prediction_ef_best_6_val ,color = 'b', s=100, marker='^', label='Val set')
ax1.scatter(y_test_ef,prediction_ef_best_6_test, color = 'r', s=100, marker='s', label='Test set')
ax1.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax1.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax1.legend()

ax2.scatter(y_train_ef,prediction_ef_best_6_train ,color = 'g', s=100, marker='o', label='Training set')
ax2.scatter(y_test_ef,prediction_ef_best_6_test, color = 'r', s=100, marker='s', label='Test set')
ax2.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax2.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax2.legend()

plt.show()
# Out:
# Mean absolute error of training set: 0.105
# Mean absolute error of validation set: 0.281
# Mean absolute error of test set: 0.278
#
#
# R^2 score on training data: 0.977
# R^2 score on validation data: 0.797
# R^2 score on test data: 0.877

# %%
## With 15 best features

# %%
best_features_15 = desc_labels[indices_ef][:15]
best_indices_15 = [feature_list.index(i) for i in best_features_15]

X_train_best_15 = X_train[X_train.columns[best_indices_15]]
X_val_best_15 = X_val[X_val.columns[best_indices_15]]
X_test_best_15 = X_test[X_test.columns[best_indices_15]]

rf_ef_best_15 = RandomForestRegressor(n_estimators = 30, random_state=16)
rf_ef_best_15.fit(X_train_best_15, y_train_ef)

prediction_ef_best_15_train = rf_ef_best_15.predict(X_train_best_15)
prediction_ef_best_15_val = rf_ef_best_15.predict(X_val_best_15)
prediction_ef_best_15_test = rf_ef_best_15.predict(X_test_best_15)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_best_15_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_best_15_val)))
print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_best_15_test)))
print('\n')

r_sq_ef_best_15_train = metrics.r2_score(y_train_ef,prediction_ef_best_15_train)
r_sq_ef_best_15_val = metrics.r2_score(y_val_ef,prediction_ef_best_15_val)
r_sq_ef_best_15_test = metrics.r2_score(y_test_ef,prediction_ef_best_15_test)

print('R^2 score on training data: {:0.3f}'.format(r_sq_ef_best_15_train))
print('R^2 score on validation data: {:0.3f}'.format(r_sq_ef_best_15_val))
print('R^2 score on test data: {:0.3f}'.format(r_sq_ef_best_15_test))

fig,(ax1,ax2) = plt.subplots(1,2,figsize = (15,7))
ax1.scatter(y_train_ef,prediction_ef_best_15_train ,color = 'g', s=100, marker='o', label='Training set')
ax1.scatter(y_val_ef,prediction_ef_best_15_val ,color = 'b', s=100, marker='^', label='Val set')
ax1.scatter(y_test_ef,prediction_ef_best_15_test, color = 'r', s=100, marker='s', label='Test set')
ax1.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax1.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax1.legend()

ax2.scatter(y_train_ef,prediction_ef_best_15_train ,color = 'g', s=100, marker='o', label='Training set')
ax2.scatter(y_test_ef,prediction_ef_best_15_test, color = 'r', s=100, marker='s', label='Test set')
ax2.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax2.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax2.legend()

plt.show()
# Out:
# Mean absolute error of training set: 0.093
# Mean absolute error of validation set: 0.273
# Mean absolute error of test set: 0.269
#
#
# R^2 score on training data: 0.983
# R^2 score on validation data: 0.829
# R^2 score on test data: 0.893

# %%
## With 38 best features

# %%
best_features_38 = desc_labels[indices_ef][:38]
best_indices_38 = [feature_list.index(i) for i in best_features_38]

X_train_best_38 = X_train[X_train.columns[best_indices_38]]
X_val_best_38 = X_val[X_val.columns[best_indices_38]]
X_test_best_38 = X_test[X_test.columns[best_indices_38]]

rf_ef_best_38 = RandomForestRegressor(n_estimators = 30, random_state=16)
rf_ef_best_38.fit(X_train_best_38, y_train_ef)

prediction_ef_best_38_train = rf_ef_best_38.predict(X_train_best_38)
prediction_ef_best_38_val = rf_ef_best_38.predict(X_val_best_38)
prediction_ef_best_38_test = rf_ef_best_38.predict(X_test_best_38)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_best_38_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_best_38_val)))
print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_best_38_test)))
print('\n')

r_sq_ef_best_38_train = metrics.r2_score(y_train_ef,prediction_ef_best_38_train)
r_sq_ef_best_38_val = metrics.r2_score(y_val_ef,prediction_ef_best_38_val)
r_sq_ef_best_38_test = metrics.r2_score(y_test_ef,prediction_ef_best_38_test)

print('R^2 score on training data: {:0.3f}'.format(r_sq_ef_best_38_train))
print('R^2 score on validation data: {:0.3f}'.format(r_sq_ef_best_38_val))
print('R^2 score on test data: {:0.3f}'.format(r_sq_ef_best_38_test))

fig,(ax1,ax2) = plt.subplots(1,2,figsize = (15,7))
ax1.scatter(y_train_ef,prediction_ef_best_38_train ,color = 'g', s=100, marker='o', label='Training set')
ax1.scatter(y_val_ef,prediction_ef_best_38_val ,color = 'b', s=100, marker='^', label='Val set')
ax1.scatter(y_test_ef,prediction_ef_best_38_test, color = 'r', s=100, marker='s', label='Test set')
ax1.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax1.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax1.legend()

ax2.scatter(y_train_ef,prediction_ef_best_38_train ,color = 'g', s=100, marker='o', label='Training set')
ax2.scatter(y_test_ef,prediction_ef_best_38_test, color = 'r', s=100, marker='s', label='Test set')
ax2.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax2.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax2.legend()

plt.show()
# Out:
# Mean absolute error of training set: 0.092
# Mean absolute error of validation set: 0.281
# Mean absolute error of test set: 0.255
#
#
# R^2 score on training data: 0.983
# R^2 score on validation data: 0.820
# R^2 score on test data: 0.907

# %% [markdown]
# ### Grid Search with Cross Validation - hyperparameter tuning

# %%
param_grid_ef = {'n_estimators': [10,20,30,50,70,100,120,150,200],
             'max_depth': [None,5,10,15,20,25,30,40,50],
             'max_features': [1,10,20,30,40,55],
              'min_samples_split': [2,4,6,8,10],
              'min_samples_leaf': [1,2,3,4,5,6],
             }

rf_ef_hp = RandomForestRegressor(random_state=16)
grid_search_ef_hp = GridSearchCV(estimator = rf_ef_hp, param_grid = param_grid_ef, 
                               scoring = 'neg_mean_absolute_error', cv = 10, n_jobs = -1, verbose = 2) ## 11

grid_search_ef_hp.fit(X_train, y_train_ef)

rf_ef_hp = RandomForestRegressor(**grid_search_ef_hp.best_params_, random_state=16)
rf_ef_hp.fit(X_train, y_train_ef)
# Out:
# Fitting 10 folds for each of 14580 candidates, totalling 145800 fits
# RandomForestRegressor(max_depth=15, max_features=20, n_estimators=120,
#                       random_state=16)

# %%
prediction_ef_hp_train = rf_ef_hp.predict(X_train)
prediction_ef_hp_val = rf_ef_hp.predict(X_val)
prediction_ef_hp_test = rf_ef_hp.predict(X_test)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_hp_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_hp_val)))
print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_hp_test)))
print('\n')

r2_ef_hp_train = metrics.r2_score(y_train_ef,prediction_ef_hp_train)
r2_ef_hp_val = metrics.r2_score(y_val_ef,prediction_ef_hp_val)
r2_ef_hp_test = metrics.r2_score(y_test_ef,prediction_ef_hp_test)

print('R^2 score on training data: {:0.3f}'.format(r2_ef_hp_train))
print('R^2 score on validation data: {:0.3f}'.format(r2_ef_hp_val))
print('R^2 score on test data: {:0.3f}'.format(r2_ef_hp_test))

fig,(ax1,ax2) = plt.subplots(1,2,figsize = (15,7))
ax1.scatter(y_train_ef,prediction_ef_hp_train ,color = 'g', s=100, marker='o', label='Training set')
ax1.scatter(y_val_ef,prediction_ef_hp_val ,color = 'b', s=100, marker='^', label='Val set')
ax1.scatter(y_test_ef,prediction_ef_hp_test, color = 'r', s=100, marker='s', label='Test set')
ax1.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax1.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
plt.legend()

ax2.scatter(y_train_ef,prediction_ef_hp_train ,color = 'g', s=100, marker='o', label='Training set')
ax2.scatter(y_test_ef,prediction_ef_hp_test, color = 'r', s=100, marker='s', label='Test set')
ax2.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax2.set_xlabel('Calculated Energy'),ax2.set_ylabel('Predicted Energy')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
# Mean absolute error of training set: 0.085
# Mean absolute error of validation set: 0.258
# Mean absolute error of test set: 0.242
#
#
# R^2 score on training data: 0.985
# R^2 score on validation data: 0.837
# R^2 score on test data: 0.911

# %%
grid_search_ef_hp.best_params_
# {'max_depth': 15,
#  'max_features': 20,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 120}
# Out:
# {'max_depth': 15,
#  'max_features': 20,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 120}

# %%
# Export parameters

parameters_ef_hp_RF = {'max_depth': rf_ef_hp.max_depth,
                                 'max_features': rf_ef_hp.max_features,
                                 'min_samples_leaf': rf_ef_hp.min_samples_leaf,
                                 'min_samples_split': rf_ef_hp.min_samples_split,
                                 'n_estimators': rf_ef_hp.n_estimators,
                                 'train_R2': metrics.r2_score(y_train_ef,prediction_ef_hp_train),
                                 'val_R2': metrics.r2_score(y_val_ef,prediction_ef_hp_val),
                                 'test_R2': metrics.r2_score(y_test_ef,prediction_ef_hp_test),
                                 'train_MAE': metrics.mean_absolute_error(y_train_ef,prediction_ef_hp_train),
                                 'val_MAE': metrics.mean_absolute_error(y_val_ef,prediction_ef_hp_val),
                                 'test_MAE': metrics.mean_absolute_error(y_test_ef,prediction_ef_hp_test),
}

parameters_ef_hp_RF_pd = pd.DataFrame(parameters_ef_hp_RF,index=[0])
parameters_ef_hp_RF_pd.to_csv('Results_Ef/parameters_ef_hp_RF_pd.csv',index=False)

# %%
importances_ef_hp = rf_ef_hp.feature_importances_
indices_ef_hp = np.argsort(importances_ef_hp)[::-1]  ## without [::-1] gives ascending order

plt.figure(figsize=(20,10))
plt.ylabel('Feature Importance')
plt.xlabel('Descriptors')
plt.bar(range(X_train.shape[1]), importances_ef_hp[indices_ef_hp], align='center')
desc_labels = df.columns[26:]
plt.xticks(range(X_train.shape[1]), desc_labels[indices_ef_hp],  rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.ylabel('Feature Importance')
plt.xlabel('Descriptors')
plt.bar(range(6), importances_ef_hp[indices_ef_hp][:6], align='center')
desc_labels = df.columns[26:]
plt.xticks(range(6), desc_labels[indices_ef_hp][:6],  rotation=90)
plt.xlim([-0.5, 5.5])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.ylabel('Feature Importance')
plt.xlabel('Descriptors')
plt.bar(range(15), importances_ef_hp[indices_ef_hp][:15], align='center')
desc_labels = df.columns[26:]
plt.xticks(range(15), desc_labels[indices_ef_hp][:15],  rotation=90)
plt.xlim([-0.5, 14.5])
plt.show()

# %%
# Extract the features importance

data_feature_imp_hp = {'feature': desc_labels[indices_ef_hp],
                   'importance':importances_ef_hp[indices_ef_hp]}
pd_feature_imp_hp = pd.DataFrame(data_feature_imp_hp)
pd_feature_imp_hp.to_csv('Results_Ef/feature_importance_ef_RF_hp.csv',index=False)

# %%
prediction_ef_train_pd_hp = pd.DataFrame(prediction_ef_hp_train)
prediction_ef_val_pd_hp = pd.DataFrame(prediction_ef_hp_val)
prediction_ef_test_pd_hp = pd.DataFrame(prediction_ef_hp_test)

prediction_ef_train_pd_hp.to_csv('Results_Ef/y_pred_train_ef_RF_hp.csv',index=False)
prediction_ef_val_pd_hp.to_csv('Results_Ef/y_pred_val_ef_RF_hp.csv',index=False)
prediction_ef_test_pd_hp.to_csv('Results_Ef/y_pred_test_ef_RF_hp.csv',index=False)

# %%
## scatter plots of top 6 descriptors

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(nrows=2,ncols=3,figsize=(18,12))


ax1.scatter(df[desc_labels[indices_ef_hp][0]],df['Ef_per_cell'])
ax1.set_xlabel(''),ax1.set_ylabel('Ef_per_cell'), ax1.set_title(desc_labels[indices_ef_hp][0])

ax2.scatter(df[desc_labels[indices_ef_hp][1]],df['Ef_per_cell'])
ax2.set_xlabel(''),ax2.set_ylabel(''), ax2.set_title(desc_labels[indices_ef_hp][1])

ax3.scatter(df[desc_labels[indices_ef_hp][2]],df['Ef_per_cell'])
ax3.set_xlabel('descriptors'),ax3.set_ylabel(''), ax3.set_title(desc_labels[indices_ef_hp][2])

ax4.scatter(df[desc_labels[indices_ef_hp][3]],df['Ef_per_cell'])
ax4.set_xlabel('descriptors'),ax4.set_ylabel('Ef_per_cell'), ax4.set_title(desc_labels[indices_ef_hp][3])

ax5.scatter(df[desc_labels[indices_ef_hp][4]],df['Ef_per_cell'])
ax5.set_xlabel(''),ax5.set_ylabel(''), ax5.set_title(desc_labels[indices_ef_hp][4])

ax6.scatter(df[desc_labels[indices_ef_hp][5]],df['Ef_per_cell'])
ax6.set_xlabel('descriptors'),ax6.set_ylabel(''), ax6.set_title(desc_labels[indices_ef_hp][5])

plt.show()

# %%
## Scatter plots of top 15 descriptors

# %%
fig, ax = plt.subplots(nrows = 5, ncols = 3, figsize = (18, 30))

nrows = 5
ncols = 3
count = 0
for i in range(nrows):
    for j in range(ncols):
        
        ax[i,j].scatter(df[desc_labels[indices_ef_hp][count]],df['Ef_per_cell'])
        ax[i,j].set_xlabel(''), ax[i,j].set_ylabel('Ef_per_cell'), ax[i,j].set_title(desc_labels[indices_ef_hp][count])
        
        count = count+1

plt.show()

# %%
## With 6 best features

# %%
best_features_6_hp = desc_labels[indices_ef_hp][:6]
best_indices_6_hp = [feature_list.index(i) for i in best_features_6_hp]

X_train_best_6_hp = X_train[X_train.columns[best_indices_6_hp]]
X_val_best_6_hp = X_val[X_val.columns[best_indices_6_hp]]
X_test_best_6_hp = X_test[X_test.columns[best_indices_6_hp]]

rf_ef_best_6_hp = RandomForestRegressor(n_estimators = 30, random_state=16)
rf_ef_best_6_hp.fit(X_train_best_6_hp, y_train_ef)

prediction_ef_best_6_hp_train = rf_ef_best_6_hp.predict(X_train_best_6_hp)
prediction_ef_best_6_hp_val = rf_ef_best_6_hp.predict(X_val_best_6_hp)
prediction_ef_best_6_hp_test = rf_ef_best_6_hp.predict(X_test_best_6_hp)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_best_6_hp_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_best_6_hp_val)))
print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_best_6_hp_test)))
print('\n')

r_sq_ef_best_6_hp_train = metrics.r2_score(y_train_ef,prediction_ef_best_6_hp_train)
r_sq_ef_best_6_hp_val = metrics.r2_score(y_val_ef,prediction_ef_best_6_hp_val)
r_sq_ef_best_6_hp_test = metrics.r2_score(y_test_ef,prediction_ef_best_6_hp_test)

print('R^2 score on training data: {:0.3f}'.format(r_sq_ef_best_6_hp_train))
print('R^2 score on validation data: {:0.3f}'.format(r_sq_ef_best_6_hp_val))
print('R^2 score on test data: {:0.3f}'.format(r_sq_ef_best_6_hp_test))

fig,(ax1,ax2) = plt.subplots(1,2,figsize = (15,7))
ax1.scatter(y_train_ef,prediction_ef_best_6_hp_train ,color = 'g', s=100, marker='o', label='Training set')
ax1.scatter(y_val_ef,prediction_ef_best_6_hp_val ,color = 'b', s=100, marker='^', label='Val set')
ax1.scatter(y_test_ef,prediction_ef_best_6_hp_test, color = 'r', s=100, marker='s', label='Test set')
ax1.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax1.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax1.legend()

ax2.scatter(y_train_ef,prediction_ef_best_6_hp_train ,color = 'g', s=100, marker='o', label='Training set')
ax2.scatter(y_test_ef,prediction_ef_best_6_hp_test, color = 'r', s=100, marker='s', label='Test set')
ax2.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax2.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax2.legend()

plt.show()
# Out:
# Mean absolute error of training set: 0.110
# Mean absolute error of validation set: 0.366
# Mean absolute error of test set: 0.351
#
#
# R^2 score on training data: 0.975
# R^2 score on validation data: 0.743
# R^2 score on test data: 0.829

# %%
## With 50 best features

# %%
best_features_50_hp = desc_labels[indices_ef_hp][:50]
best_indices_50_hp = [feature_list.index(i) for i in best_features_50_hp]

X_train_best_50_hp = X_train[X_train.columns[best_indices_50_hp]]
X_val_best_50_hp = X_val[X_val.columns[best_indices_50_hp]]
X_test_best_50_hp = X_test[X_test.columns[best_indices_50_hp]]

rf_ef_best_50_hp = RandomForestRegressor(n_estimators = 30, random_state=16)
rf_ef_best_50_hp.fit(X_train_best_50_hp, y_train_ef)

prediction_ef_best_50_hp_train = rf_ef_best_50_hp.predict(X_train_best_50_hp)
prediction_ef_best_50_hp_val = rf_ef_best_50_hp.predict(X_val_best_50_hp)
prediction_ef_best_50_hp_test = rf_ef_best_50_hp.predict(X_test_best_50_hp)

print('Mean absolute error of training set: {:0.3f}'.format(metrics.mean_absolute_error(y_train_ef,prediction_ef_best_50_hp_train)))
print('Mean absolute error of validation set: {:0.3f}'.format(metrics.mean_absolute_error(y_val_ef,prediction_ef_best_50_hp_val)))
print('Mean absolute error of test set: {:0.3f}'.format(metrics.mean_absolute_error(y_test_ef,prediction_ef_best_50_hp_test)))
print('\n')

r_sq_ef_best_50_hp_train = metrics.r2_score(y_train_ef,prediction_ef_best_50_hp_train)
r_sq_ef_best_50_hp_val = metrics.r2_score(y_val_ef,prediction_ef_best_50_hp_val)
r_sq_ef_best_50_hp_test = metrics.r2_score(y_test_ef,prediction_ef_best_50_hp_test)

print('R^2 score on training data: {:0.3f}'.format(r_sq_ef_best_50_hp_train))
print('R^2 score on validation data: {:0.3f}'.format(r_sq_ef_best_50_hp_val))
print('R^2 score on test data: {:0.3f}'.format(r_sq_ef_best_50_hp_test))

fig,(ax1,ax2) = plt.subplots(1,2,figsize = (15,7))
ax1.scatter(y_train_ef,prediction_ef_best_50_hp_train ,color = 'g', s=100, marker='o', label='Training set')
ax1.scatter(y_val_ef,prediction_ef_best_50_hp_val ,color = 'b', s=100, marker='^', label='Val set')
ax1.scatter(y_test_ef,prediction_ef_best_50_hp_test, color = 'r', s=100, marker='s', label='Test set')
ax1.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax1.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax1.legend()

ax2.scatter(y_train_ef,prediction_ef_best_50_hp_train ,color = 'g', s=100, marker='o', label='Training set')
ax2.scatter(y_test_ef,prediction_ef_best_50_hp_test, color = 'r', s=100, marker='s', label='Test set')
ax2.plot([-9,-4],[-9,-4],color='gray',linestyle='dashed',linewidth=2.5)
ax2.set_xlabel('Calculated Energy'),ax1.set_ylabel('Predicted Energy')
ax2.legend()

plt.show()
# Out:
# Mean absolute error of training set: 0.089
# Mean absolute error of validation set: 0.285
# Mean absolute error of test set: 0.269
#
#
# R^2 score on training data: 0.983
# R^2 score on validation data: 0.817
# R^2 score on test data: 0.893

# %%
## Performance of RF model with the training size

# %%
final_training_R2_scores = []
final_test_R2_scores = []
final_training_MAE_scores = []
final_test_MAE_scores = []

split_ratio = [0.05,0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.8]
for i in range(len(split_ratio)):
    intermediate_training_R2_scores =[]
    intermediate_test_R2_scores = []
    intermediate_training_MAE_scores = []
    intermediate_test_MAE_scores = []
    
    for j in range(30):
        X_train_ef,X_test_ef,y_train_ef,y_test_ef= train_test_split(X_ef, y_ef, test_size=1-split_ratio[i])
        
        rf_ef= RandomForestRegressor(n_estimators = 30, random_state=2)
        rf_ef.fit(X_train_ef, y_train_ef.ravel())
        
        prediction_ef_train= rf_ef.predict(X_train_ef)
        prediction_ef_test= rf_ef.predict(X_test_ef)
        
        r_sq_ef_train= metrics.r2_score(y_train_ef,prediction_ef_train)
        r_sq_ef_test= metrics.r2_score(y_test_ef,prediction_ef_test)
        
        mae_ef_train= metrics.mean_absolute_error(y_train_ef,prediction_ef_train)
        mae_ef_test= metrics.mean_absolute_error(y_test_ef,prediction_ef_test)
        
        intermediate_training_R2_scores.append(r_sq_ef_train)
        intermediate_test_R2_scores.append(r_sq_ef_test)
        
        intermediate_training_MAE_scores.append(mae_ef_train)
        intermediate_test_MAE_scores.append(mae_ef_test)
    
    final_training_R2_scores.append(intermediate_training_R2_scores)
    final_test_R2_scores.append(intermediate_test_R2_scores)  
    
    final_training_MAE_scores.append(intermediate_training_MAE_scores)
    final_test_MAE_scores.append(intermediate_test_MAE_scores)
    
# final_train_scores, final_test_scores
avg_training_R2_score = []
std_training_R2_score = []
avg_training_MAE_score = []
std_training_MAE_score = []

avg_test_R2_score = []
std_test_R2_score = []
avg_test_MAE_score = []
std_test_MAE_score = []

for i in range(len(final_training_R2_scores)):
    avg_training_R2_score.append(mean(final_training_R2_scores[i]))
    avg_test_R2_score.append(mean(final_test_R2_scores[i]))
    
    std_training_R2_score.append(std(final_training_R2_scores[i]))
    std_test_R2_score.append(std(final_test_R2_scores[i]))
    
    avg_training_MAE_score.append(mean(final_training_MAE_scores[i]))
    avg_test_MAE_score.append(mean(final_test_MAE_scores[i]))
    
    std_training_MAE_score.append(std(final_training_MAE_scores[i]))
    std_test_MAE_score.append(std(final_test_MAE_scores[i]))
    
# Plot
plt.figure(figsize=(15,10))
plot(split_ratio, avg_test_R2_score, linewidth= 3, color='orange', marker = 'o', linestyle='dotted', label = 'R2 score', markersize=10)
errorbar(split_ratio, avg_test_R2_score, linewidth= 3, color='orange', yerr = std_test_R2_score, linestyle='dotted')
plot(split_ratio, avg_test_MAE_score, linewidth= 3, color='black', marker='s', linestyle='dotted', label = 'MAE', markersize=10)
errorbar(split_ratio, avg_test_MAE_score, linewidth= 3, color='black', yerr = std_test_MAE_score, linestyle='dotted')

plt.xlabel('Training set size')
plt.ylabel('Test set score')
plt.legend(loc='center right')
plt.show()

# %%
# Plot
plt.figure(figsize=(7,7))
plot(split_ratio, avg_test_R2_score, linewidth= 3, color='blue', marker = 'o', linestyle='dotted', label = 'R2 score', markersize=10)
errorbar(split_ratio, avg_test_R2_score, linewidth= 3, color='blue', yerr = std_test_R2_score, linestyle='dotted')
plot(split_ratio, avg_test_MAE_score, linewidth= 3, color='black', marker='s', linestyle='dotted', label = 'MAE', markersize=10)
errorbar(split_ratio, avg_test_MAE_score, linewidth= 3, color='black', yerr = std_test_MAE_score, linestyle='dotted')
plt.xlabel('Training set size')
plt.ylabel('Test set score')
plt.legend(loc='center right')
plt.show()

# %%
#Export the result

training_set_size_pd = pd.DataFrame({'split_ratio': split_ratio,
                                     'avg_train_R2_score': avg_training_R2_score,
                                     'avg_test_R2_score': avg_test_R2_score,
                                     'avg_train_MAE_score': avg_training_MAE_score,
                                     'avg_test_MAE_score': avg_test_MAE_score,
                                     
                                     'std_train_R2_score': std_training_R2_score,
                                     'std_test_R2_score': std_test_R2_score,
                                     'std_train_MAE_score': std_training_MAE_score,
                                     'std_test_MAE_score': std_test_MAE_score,
                                    })
training_set_size_pd.to_csv('Results_Ef/training_set_size_RF_ef.csv',index=False)

# %%
## Predicting the chemical space

# %%
# test_data_1 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_1.csv')
# test_data_2 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_2.csv')
# test_data_3 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_3.csv')
# test_data_4 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_4.csv')
# test_data_5 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_5.csv')
# test_data_6 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_6.csv')
# test_data_7 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_7.csv')
# test_data_8 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_8.csv')
# test_data_9 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_9.csv')
# test_data_10 = pd.read_csv('../chemical_space/withDescriptors_FULLspace_hetero_10.csv')

# %%
# X_test_data_1 = test_data_1[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_2 = test_data_2[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_3 = test_data_3[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_4 = test_data_4[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_5 = test_data_5[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_6 = test_data_6[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_7 = test_data_7[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_8 = test_data_8[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_9 = test_data_9[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# X_test_data_10 = test_data_10[['avg_vdw_radius', 'delta_a1a2_vdw_radius', 'delta_bx_vdw_radius', 'max_diff_vdw_radius', 'std_vdw_radius', 
#            'avg_covalent_radius', 'delta_a1a2_covalent_radius', 'delta_bx_covalent_radius', 'max_diff_covalent_radius', 
#            'std_covalent_radius', 'avg_atomic_radius', 'delta_a1a2_atomic_radius', 'delta_bx_atomic_radius', 'max_diff_atomic_radius', 
#            'std_atomic_radius', 'avg_atomic_volume', 'delta_a1a2_atomic_volume', 'delta_bx_atomic_volume', 'max_diff_atomic_volume', 
#            'std_atomic_volume', 'avg_dipole_polarizability', 'delta_a1a2_dipole_polarizability', 'delta_bx_dipole_polarizability', 
#            'max_diff_dipole_polarizability', 'std_dipole_polarizability', 'avg_val_electrons', 'delta_a1a2_val_electrons', 
#            'delta_bx_val_electrons', 'max_diff_val_electrons', 'std_val_electrons', 'avg_unp_electrons', 'delta_a1a2_unp_electrons',
#            'delta_bx_unp_electrons', 'max_diff_unp_electrons', 'std_unp_electrons', 'avg_ion_energies', 'delta_a1a2_ion_energies', 
#            'delta_bx_ion_energies', 'max_diff_ion_energies', 'std_ion_energies', 'avg_no_electrons', 'delta_a1a2_no_electrons', 
#            'delta_bx_no_electrons', 'max_diff_no_electrons', 'std_no_electrons', 'avg_electronegativity', 'delta_a1a2_electronegativity',
#            'delta_bx_electronegativity', 'max_diff_electronegativity', 'std_electronegativity', 'avg_electron_affinity', 
#            'delta_a1a2_electron_affinity', 'delta_bx_electron_affinity', 'max_diff_electron_affinity', 'std_electron_affinity']]

# %%
# best_features

# %%
# ## Considering only 14 best features

# X_test_data_1_best = X_test_data_1[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_2_best = X_test_data_2[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_3_best = X_test_data_3[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_4_best = X_test_data_4[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_5_best = X_test_data_5[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_6_best = X_test_data_6[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_7_best = X_test_data_7[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_8_best = X_test_data_8[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_9_best = X_test_data_9[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# X_test_data_10_best = X_test_data_10[['std_no_electrons','std_electronegativity','std_atomic_radius','delta_bx_atomic_radius','std_covalent_radius',
#                              'delta_bx_no_electrons','avg_no_electrons','delta_bx_electronegativity','delta_bx_covalent_radius',
#                              'std_atomic_volume','avg_electron_affinity','avg_electronegativity','std_ion_energies','delta_a1a2_electronegativity']]

# %%
# X_test_data_1_best = np.array(X_test_data_1_best)
# X_test_data_2_best = np.array(X_test_data_2_best)
# X_test_data_3_best = np.array(X_test_data_3_best)
# X_test_data_4_best = np.array(X_test_data_4_best)
# X_test_data_5_best = np.array(X_test_data_5_best)
# X_test_data_6_best = np.array(X_test_data_6_best)
# X_test_data_7_best = np.array(X_test_data_7_best)
# X_test_data_8_best = np.array(X_test_data_8_best)
# X_test_data_9_best = np.array(X_test_data_9_best)
# X_test_data_10_best = np.array(X_test_data_10_best)

# %%
# prediction_ef_test_data_1 = rf_ef_hp.predict(X_test_data_1_best)
# prediction_ef_test_data_2 = rf_ef_hp.predict(X_test_data_2_best)
# prediction_ef_test_data_3 = rf_ef_hp.predict(X_test_data_3_best)
# prediction_ef_test_data_4 = rf_ef_hp.predict(X_test_data_4_best)
# prediction_ef_test_data_5 = rf_ef_hp.predict(X_test_data_5_best)
# prediction_ef_test_data_6 = rf_ef_hp.predict(X_test_data_6_best)
# prediction_ef_test_data_7 = rf_ef_hp.predict(X_test_data_7_best)
# prediction_ef_test_data_8 = rf_ef_hp.predict(X_test_data_8_best)
# prediction_ef_test_data_9 = rf_ef_hp.predict(X_test_data_9_best)
# prediction_ef_test_data_10 = rf_ef_hp.predict(X_test_data_10_best)

# %%
# test_data_1['pred_ef'] = [i for i in prediction_ef_test_data_1]
# test_data_2['pred_ef'] = [i for i in prediction_ef_test_data_2]
# test_data_3['pred_ef'] = [i for i in prediction_ef_test_data_3]
# test_data_4['pred_ef'] = [i for i in prediction_ef_test_data_4]
# test_data_5['pred_ef'] = [i for i in prediction_ef_test_data_5]
# test_data_6['pred_ef'] = [i for i in prediction_ef_test_data_6]
# test_data_7['pred_ef'] = [i for i in prediction_ef_test_data_7]
# test_data_8['pred_ef'] = [i for i in prediction_ef_test_data_8]
# test_data_9['pred_ef'] = [i for i in prediction_ef_test_data_9]
# test_data_10['pred_ef'] = [i for i in prediction_ef_test_data_10]

# %%
# test_data_1.to_csv('chemical_space/pred_Ef_FULLspace_hetero_1.csv',index=False)
# test_data_2.to_csv('chemical_space/pred_Ef_FULLspace_hetero_2.csv',index=False)
# test_data_3.to_csv('chemical_space/pred_Ef_FULLspace_hetero_3.csv',index=False)
# test_data_4.to_csv('chemical_space/pred_Ef_FULLspace_hetero_4.csv',index=False)
# test_data_5.to_csv('chemical_space/pred_Ef_FULLspace_hetero_5.csv',index=False)
# test_data_6.to_csv('chemical_space/pred_Ef_FULLspace_hetero_6.csv',index=False)
# test_data_7.to_csv('chemical_space/pred_Ef_FULLspace_hetero_7.csv',index=False)
# test_data_8.to_csv('chemical_space/pred_Ef_FULLspace_hetero_8.csv',index=False)
# test_data_9.to_csv('chemical_space/pred_Ef_FULLspace_hetero_9.csv',index=False)
# test_data_10.to_csv('chemical_space/pred_Ef_FULLspace_hetero_10.csv',index=False)
